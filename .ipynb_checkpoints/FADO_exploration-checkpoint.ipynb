# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
from specutils import Spectrum1D

# %% [markdown]
# *EL.fits: EL__FITS= 'Fitted Emission-Lines!'
# *1D.fits: SPEC__1D= 'Spectra from FADO population synthesis'
# *ST.fits:  ST__FITS= 'Statistics & products!'
# *DE.fits:

# %%
files = glob.glob("*.fits")
for f in files:
    hdu = fits.open(f)
    head = hdu[0].header
    print("-"*20)
    print(f)
    print(hdu.info())
    print(list(head.keys())  )
    #print(repr(head))
    hdu.close()
# Out:
# --------------------
# spec_wcs1d_p17q10_new_der.fits.output3_EL.fits
# Filename: spec_wcs1d_p17q10_new_der.fits.output3_EL.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     101   (1071, 3)   float32
# None
# ['SIMPLE', 'BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'EXTEND', 'COMMENT', 'FADO_VER', 'ODIE_VER', 'OBJ_TYPE', 'EL__FITS', 'ARQ_BASE', 'ARQ_CONF', 'ARQ_MASK', 'R_LAWOPT', 'NE_LINES', 'N_PARAMS', 'TOTLINES', 'ISNEBCON', 'ISNEBCPL', 'ISLEAKON', 'SELF_CON', 'CONVERGE', 'FLAG_BPT', 'ELAPSEDT', 'LAMBDA_0', 'GALSNORM', 'FLUXUNIT', 'LOGBN2HA', 'LOGBN2HA', 'ERRBN2HA', 'LOGBO3HB', 'ERRBO3HB', 'TELECTRO', 'DELECTRO', 'GEXTINCT', 'GEXTBDEV', 'GNEBULAR', 'GNEBBDEV', 'ORDERPAR', 'ORDERNUM', 'ROW_NUM1', 'ROW_NUM2', 'ROW_NUM3', 'BLOCK__1', 'BLOCK__2', 'BLOCK__3', 'EL_____1', 'EL_____2', 'EL_____3', 'EL_____4', 'EL_____5', 'EL_____6', 'EL_____7', 'EL_____8', 'EL_____9', 'EL____10', 'EL____11', 'EL____12', 'EL____13', 'EL____14', 'EL____15', 'EL____16', 'EL____17', 'EL____18', 'EL____19', 'EL____20', 'EL____21', 'EL____22', 'EL____23', 'EL____24', 'EL____25', 'EL____26', 'EL____27', 'EL____28', 'EL____29', 'EL____30', 'EL____31', 'EL____32', 'EL____33', 'EL____34', 'EL____35', 'EL____36', 'EL____37', 'EL____38', 'EL____39', 'EL____40', 'EL____41', 'EL____42', 'EL____43', 'EL____44', 'EL____45', 'EL____46', 'EL____47', 'EL____48', 'EL____49', 'EL____50', 'EL____51', 'CRVAL1', 'CRPIX1', 'CDELT1']
# --------------------
# spec_wcs1d_p17q10_new_der.fits.output3_1D.fits
# Filename: spec_wcs1d_p17q10_new_der.fits.output3_1D.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      56   (4081, 19)   float32
# None
# ['SIMPLE', 'BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'EXTEND', 'COMMENT', 'FADO_VER', 'ODIE_VER', 'OBJ_TYPE', 'SPEC__1D', 'ARQ_BASE', 'ARQ_CONF', 'ARQ_MASK', 'R_LAWOPT', 'NUMPARAM', 'NUM_BASE', 'NINDIVID', 'NLEFFECT', 'NGLAMBDA', 'ISNEBCON', 'ISNEBCPL', 'ISLEAKON', 'SELF_CON', 'CONVERGE', 'ELAPSEDT', 'LAMBDA_0', 'GALSNORM', 'FLUXUNIT', 'CHI2_VAL', 'CHI2_DEV', 'CHI2_RED', 'L_DISMPC', 'OLSYNINI', 'OLSYNFIN', 'OLSYNDEL', 'LAMBDA_I', 'LAMBDA_F', 'REDSHIFT', 'REDERROR', 'CRVAL1', 'CRPIX1', 'CDELT1', 'ROWNUM01', 'ROWNUM02', 'ROWNUM03', 'ROWNUM04', 'ROWNUM05', 'ROWNUM06', 'ROWNUM07', 'ROWNUM08', 'ROWNUM09', 'ROWNUM10', 'ROWNUM11', 'ROWNUM12', 'ROW13-XX']
# --------------------
# spec_wcs1d_p17q10_new_der.fits.output3_ST.fits
# Filename: spec_wcs1d_p17q10_new_der.fits.output3_ST.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     230   (7, 100)   float32
# None
# ['SIMPLE', 'BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'EXTEND', 'COMMENT', 'FADO_VER', 'ODIE_VER', 'OBJ_TYPE', 'ST__FITS', 'ARQ_BASE', 'ARQ_CONF', 'ARQ_MASK', 'R_LAWOPT', 'NUMPARAM', 'NUM_BASE', 'NINDIVID', 'NLEFFECT', 'ISNEBCON', 'ISNEBCPL', 'ISLEAKON', 'SELF_CON', 'FLAG_BPT', 'ELAPSEDT', 'LAMBDA_0', 'GALSNORM', 'FLUXUNIT', 'L_DISMPC', 'TELECTRO', 'DELECTRO', 'GEXTINCT', 'GEXTBAVE', 'GEXTBDEV', 'GNEBULAR', 'GNEBBAVE', 'GNEBBDEV', 'V0SYSGAL', 'V0SYSAVE', 'V0SYSDEV', 'VTSYSGAL', 'VTSYSAVE', 'VTSYSDEV', 'VDSYSGAL', 'VDSYSAVE', 'VDSYSDEV', 'V0NEBGAL', 'V0NEBAVE', 'V0NEBDEV', 'VTNEBGAL', 'VTNEBAVE', 'VTNEBDEV', 'VDNEBGAL', 'VDNEBAVE', 'VDNEBDEV', 'PRODUCTS', 'MEAN_AGE', 'BST_LAGE', 'AVE_LAGE', 'DEV_LAGE', 'BST_MAGE', 'AVE_MAGE', 'DEV_MAGE', 'BSTLLAGE', 'AVELLAGE', 'DEVLLAGE', 'BSTLMAGE', 'AVELMAGE', 'DEVLMAGE', 'MEAN_MET', 'BST_LMET', 'AVE_LMET', 'DEV_LMET', 'BST_MMET', 'AVE_MMET', 'DEV_MMET', 'MASSEVER', 'LOGMEBST', 'LOGMEAVE', 'LOGMEDEV', 'MASSCORR', 'LOGMCBST', 'LOGMCAVE', 'LOGMCDEV', 'ME__PAGB', 'LOGPEBST', 'LOGPEAVE', 'LOGPEDEV', 'MC__PAGB', 'LOGPCBST', 'LOGPCAVE', 'LOGPCDEV', 'LOG____L', 'LOG_LGAL', 'LOG_LAVE', 'LOG_LDEV', 'LUM_1GYR', 'LBST1GYR', 'LAVE1GYR', 'LDEV1GYR', 'LUM_5GYR', 'LBST5GYR', 'LAVE5GYR', 'LDEV5GYR', 'LOG___QH', 'BSTLOGQH', 'AVELOGQH', 'DEVLOGQH', 'LOG_QHEI', 'BLG_QHEI', 'ALG_QHEI', 'DLG_QHEI', 'LOGQHEII', 'BLGQHEII', 'ALGQHEII', 'DLGQHEII', 'BALMER_P', 'FBST__HA', 'FAVE__HA', 'FDEV__HA', 'EWBST_HA', 'EWAVE_HA', 'EWDEV_HA', 'FBST__HB', 'FAVE__HB', 'FDEV__HB', 'EWBST_HB', 'EWAVE_HB', 'EWDEV_HB', 'BALMER_O', 'FOBST_HA', 'FOAVE_HA', 'FOMED_HA', 'FOBSTEHA', 'FOAVEEHA', 'FOMEDEHA', 'EOBST_HA', 'EOAVE_HA', 'EOMED_HA', 'EOBSTEHA', 'EOAVEEHA', 'EOMEDEHA', 'FOBST_HB', 'FOAVE_HB', 'FOMED_HB', 'FOBSTEHB', 'FOAVEEHB', 'FOMEDEHB', 'EOBST_HB', 'EOAVE_HB', 'EOMED_HB', 'EOBSTEHB', 'EOAVEEHB', 'EOMEDEHB', 'TAURATIO', 'TAU__BST', 'TAU__AVE', 'TAU__DEV', 'TAU__EXT', 'TAURDBST', 'TAURDAVE', 'TAURDDEV', 'TAU_PAGB', 'TAUP_BST', 'TAUP_AVE', 'TAUP_DEV', 'TAUEPAGB', 'TAUPEBST', 'TAUPEAVE', 'TAUPEDEV', 'PSI_EVAL', 'PSI__BST', 'PSI__AVE', 'PSI__DEV', 'PSIEEVAL', 'PSIRDBST', 'PSIRDAVE', 'PSIRDDEV', 'ZETAEVAL', 'ZETA_BST', 'ZETA_AVE', 'ZETA_DEV', 'ZETA_EXT', 'ZETAEBST', 'ZETAEAVE', 'ZETAEDEV', 'ROWNUM_1', 'ROWNUM_2', 'ROWNUM_3', 'ROWNUM_4', 'ROWNUM_5', 'ROWNUM_6', 'ROWNUM_7', 'ROWNUM_8', 'ROWNUM_9', 'ROWNUM10', 'ROWNUM11', 'ROWNUM12', 'ROWNUM13', 'ROWNUM14', 'ROWNUM15', 'ROWNUM16', 'ROWNUM17', 'ROWNUM18', 'ROWNUM19', 'ROWNUM20', 'ROWNUM21', 'ROWNUM22', 'ROWNUM23', 'ROWNUM24', 'ROWNUM25', 'ROWNUM26', 'ROWNUM27', 'ROWNUM28', 'ROWNUM29', 'ROWNUM30', 'ROWNUM31', 'ROWNUM32', 'ROWNUM33', 'ROWNUM34', 'ROWNUM35', 'ROWNUM36', 'ROWNUM37', 'ROWNUM38', 'ROW__FLS', 'ROW__EWS', 'ROWFPAGB', 'CRVAL1', 'CRPIX1', 'CDELT1']
# --------------------
# spec_wcs1d_p17q10_new_der.fits.output3_DE.fits
# Filename: spec_wcs1d_p17q10_new_der.fits.output3_DE.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      93   (67, 43)   float32
# None
# ['SIMPLE', 'BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'EXTEND', 'COMMENT', 'FADO_VER', 'ODIE_VER', 'OBJ_TYPE', 'POPX_VEC', 'ARQ_BASE', 'ARQ_CONF', 'ARQ_MASK', 'R_LAWOPT', 'NUMPARAM', 'NUM_BASE', 'NINDIVID', 'NLEFFECT', 'ISNEBCON', 'ISNEBCPL', 'ISLEAKON', 'SELF_CON', 'FLAG_BPT', 'ELAPSEDT', 'LAMBDA_0', 'GALSNORM', 'FLUXUNIT', 'L_DISMPC', 'TELECTRO', 'DELECTRO', 'GEXTINCT', 'GEXTBDEV', 'GNEBULAR', 'GNEBBDEV', 'V0SYSGAL', 'V0SYSDEV', 'VTSYSGAL', 'VTSYSDEV', 'VDSYSGAL', 'VDSYSDEV', 'V0NEBGAL', 'V0NEBDEV', 'VTNEBGAL', 'VTNEBDEV', 'VDNEBGAL', 'VDNEBDEV', 'ORDERP_1', 'ORDERN_1', 'ORDERP_2', 'ORDERN_2', 'ORDERP_3', 'ORDERN_3', 'ORDERP_4', 'ORDERN_4', 'ORDERP_5', 'ORDERN_5', 'ORDERP_6', 'ORDERN_6', 'ORDERP_7', 'ORDERN_7', 'ORDERP_8', 'ORDERN_8', 'ORDERP_9', 'ORDERN_9', 'ORDERP10', 'ORDERN10', 'ROWNUM_1', 'ROWNUM_2', 'ROWNUM_3', 'ROWNUM_4', 'ROWNUM_5', 'ROWNUM_6', 'ROWNUM_7', 'ROWNUM_8', 'ROWNUM_9', 'ROWNUM10', 'ROWNUM11', 'ROWNUM12', 'BASEPOPX', 'BASECHI2', 'BASEADEV', 'BASEGEXT', 'ROWS_LUM', 'ROWSMCOR', 'ROWSMFOR', 'ROWS_AGE', 'ROWSLAGE', 'ROWS_MET', 'ROWS_ALP', 'CRVAL1', 'CRPIX1', 'CDELT1']

# %%
filename = "spec_wcs1d_p17q10_new_der.fits.output3_1D.fits"

oned_hdu = fits.open(filename)
data = oned_hdu[0].data
head = oned_hdu[0].header

CRVAL1 = head["CRVAL1"]
CRPIX1 = head["CRPIX1"] - 1 # because python
CRDELT1 = head["CDELT1"]

waves = CRVAL1 + CRDELT1*np.arange(0,data.shape[1],1)


plt.figure(figsize=(14,8))
for line in data:
    plt.plot(waves,line)
print(type(data[1]))
plt.xlim(4500,7000)
plt.ylim(0,10)
# Out:
# <class 'numpy.ndarray'>
# (0, 10)

# %%
filename = "spec_wcs1d_p17q10_new_der.fits.output3_EL.fits"

oned_hdu = fits.open(filename)
data = oned_hdu[0].data
head = oned_hdu[0].header

from pyFADO import FADO
fado  = FADO("spec_wcs1d_p17q10_new_der.fits.output3_EL.fits",
             "spec_wcs1d_p17q10_new_der.fits.output3_ST.fits",
             "spec_wcs1d_p17q10_new_der.fits.output3_1D.fits",
             "spec_wcs1d_p17q10_new_der.fits.output3_DE.fits")

# %%
ELs = fado.ELnames()
print(ELs)


rows = fado.ELrows()
window = rows['Halpha'].split("--")
xmin = int(window[0])-1
xmax = int(window[1])-1
print(xmin,xmax)
# Out:
# {'[NeV]': 3425.5, '[OII]': 7330.2, 'H12': 3750.2, 'H11': 3770.6, 'H10': 3797.9, 'H9': 3835.4, '[NeIII]': 3967.8, 'H8HeI': 3889.0, 'Hepsilon': 3970.1, 'HeI': 7065.2, '[SII]': 6730.8, 'Hdelta': 4101.7, 'Hgamma': 4340.5, '[OIII]': 5006.8, '[FeIII]': 5270.4, 'HeII': 4685.7, '[ArIV]': 4740.2, 'Hbeta': 4861.3, '[FeVII]': 6086.3, '[NI]': 5199.1, '[ClIII]': 5519.2, '[NII]': 6583.5, '[OI]': 6363.8, '[SIII]': 6312.1, 'Halpha': 6562.8, '[ArIII]': 7751.1, '[FeII]': 8617.0}
# 840 860

# %%
values = data[:,xmin:xmax][0]
print(values)

#values[1].shape
for v in values:
    print(v)
# Out:
# [ 6.5625151e+03  9.4141359e+00  4.6416216e+00  4.1993923e+01
#  -1.9711938e-03  1.0953178e+02  1.2930693e+02  6.5627388e+03
#   9.4157734e+00  4.6428866e+00  3.1848013e+01 -2.6437384e-03
#   1.0958069e+02  1.2951489e+02  6.5625273e+03  9.4160814e+00
#   4.6425495e+00  4.1502628e+01 -3.0365945e-03  1.0957630e+02]
# 6562.515
# 9.414136
# 4.6416216
# 41.993923
# -0.0019711938
# 109.53178
# 129.30693
# 6562.739
# 9.415773
# 4.6428866
# 31.848013
# -0.0026437384
# 109.58069
# 129.5149
# 6562.5273
# 9.416081
# 4.6425495
# 41.50263
# -0.0030365945
# 109.5763

# %%
results = fado.get_results("Hbeta")
print(results)
# Out:
# {'Lambda': 4859.8594, 'Amplitude': 3.610349, 'Sigma': 3.788332, 'Vel': 154.49683, 'shift': -0.10947938, 'Flux': 34.283657, 'EW': 45.109554}

# %%
from scipy.stats import norm

mu = results["Lambda"] 
sigma = results["Sigma"]

x = fado.waves()

# mean = 0, stddev = 1, since Z-transform was calculated
y = norm.pdf(x,0,1)


fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x,y)



#ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')
# Out:
# Text(0.5, 1.0, 'Normal Gaussian Curve')
